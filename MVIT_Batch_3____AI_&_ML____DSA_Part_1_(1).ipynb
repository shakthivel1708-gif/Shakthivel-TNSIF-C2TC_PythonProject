# %% [markdown]
# <a href="https://colab.research.google.com/github/shakthivel1708-gif/Shakthivel-TNSIF-C2TC_PythonProject/blob/main/MVIT_Batch_3____AI_%26_ML____DSA_Part_1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DSA in Python**

# %% [markdown]
# # Python Lists — DSA Theory
#
# A **List** in Python is a **dynamic, ordered, mutable sequence** of elements.
#
# ### Characteristics:
#
# * **Indexed:** Items are accessed via zero-based index.
# * **Mutable:** You can modify, add, or remove elements.
# * **Allows Duplicates:** Lists can have multiple occurrences of the same value.
# * **Heterogeneous:** Can store elements of different data types.
# * **Dynamic Size:** Lists can grow or shrink as needed during execution.
#
# ---
#
# ### Core Operations in Lists:
#
# | Operation | Description |
# | :--- | :--- |
# | `append()` | Add an element at the end |
# | `insert()` | Insert an item at a specific index |
# | `remove()` | Remove the first occurrence of a value |
# | `pop()` | Remove item at a given index (default last) |
# | `sort()` | Sort items in ascending/descending order |
# | `clear()` | Remove all items from the list |

# %% [markdown]
# Creating a List

# %%
# Creating a list
my_list = [10, 20, 30, 40, 20,"Apple",True,1.5,"Kartik"]
print("List:", my_list)
print (type(my_list))
# Out:
# List: [10, 20, 30, 40, 20, 'Apple', True, 1.5, 'Kartik']
# <class 'list'>

# %% [markdown]
# 1. append()

# %%
# append() → Adds a single element to the end of the list
numbers = [10, 20, 30]
numbers.append(40)
numbers.append(50)
print("After append:", numbers)  # [10, 20, 30, 40]
# Out:
# After append: [10, 20, 30, 40, 50]

# %% [markdown]
# 2. insert()

# %%
# insert() → Inserts an element at a specified index
numbers = [1, 3, 4,5]
numbers.insert(2,"Kartik")  # Insert 2 at index 0
print("After insert:", numbers)  # [1, 2, 3, 4]
# Out:
# After insert: [1, 3, 'Kartik', 4, 5]

# %% [markdown]
# 3. remove ()

# %%
# remove() → Removes the first occurrence of a specified value
numbers = [1,2, 4,3,2,2, 3, 2,"apple"]
numbers.remove(2)  # Removes the first occurence
print("After remove:", numbers)  # [1, 3, 2]
# Out:
# After remove: [1, 4, 3, 2, 2, 3, 2, 'apple']

# %% [markdown]
# 4. pop ()

# %%
# pop() → Removes and returns element at given index (default is last)
numbers = [10, 20, 30,40,50]
popped_value = numbers.pop(3)  # Removes 30
print("Popped value:", popped_value)
print("After pop:", numbers)  # [10, 20]
# Out:
# Popped value: 40
# After pop: [10, 20, 30, 50]

# %% [markdown]
# 5. sort ()

# %%
# sort() → Sorts the list in ascending order
numbers = [3, 1, 4, 2]
numbers.sort()
print("After sort:", numbers)  # [1, 2, 3, 4]
# Out:
# After sort: [1, 2, 3, 4]

# %% [markdown]
# 6. clear ()

# %%
# clear() → Removes all elements from the list
numbers = [10, 20, 30]
numbers.clear()
print("After clear:", numbers)  # []

# %% [markdown]
# # Python Tuples — DSA Theory
#
# A **Tuple** in Python is an **ordered, immutable sequence** of elements.
#
# ### Characteristics:
#
# * **Indexed:** Items are accessed via zero-based index.
# * **Immutable:** Elements cannot be modified, added, or removed after creation.
# * **Allows Duplicates:** Tuples can have multiple occurrences of the same value.
# * **Heterogeneous:** Can store elements of different data types.
# * **Fixed Size:** Memory efficient compared to lists due to immutability.
#
# ---
#
# ### Core Operations & Functions:
#
# | Operation / Function | Description |
# | :--- | :--- |
# | `count()` | Count total occurrences of a value |
# | `index()` | Return index of first matching value |
# | `len()` | Get the total length of the tuple |
# | `tuple()` | Convert another data type (like a list) into a tuple |

# %%
# Create a sample tuple
numbers = (10, 20, 30, 20, 40)

# 1. count() — Count total occurrences of a value
print(numbers.count(20))  # Output: 2

# 2. index() — Return index of first matching value
print(numbers.index(30))  # Output: 2

# 3. len() — Get the total length of the tuple
print(len(numbers))       # Output: 5

# 4. tuple() — Convert another data type (like a list) into a tuple
my_list = [1, 2, 3]
my_tuple = tuple(my_list)
print(my_tuple)           # Output: (1, 2, 3)
# Out:
# 2
# 2
# 5
# (1, 2, 3)

# %% [markdown]
# # Python Dictionaries — DSA Theory
#
# A **Dictionary** in Python is an **unordered, mutable collection** of key-value pairs.
#
# ### Characteristics:
#
# * **Key-Value Pairs:** Stores data as `key: value` associations.
# * **Unique Keys:** Keys must be unique and immutable (e.g., strings, numbers, tuples).
# * **Mutable:** Values can be updated, added, or removed.
# * **Fast Lookups:** Optimized for instant key-based data retrieval ($O(1)$ average time complexity).
#
# ---
#
# ### Core Operations in Dictionaries:
#
# | Operation | Description |
# | :--- | :--- |
# | `dict[key]` | Access value by key |
# | `get()` | Safely retrieve value without raising an error if key missing |
# | `keys()` | Return a list-like view of all keys |
# | `values()` | Return a list-like view of all values |
# | `items()` | Return key-value pairs as tuples |
# | `pop()` | Remove and return value for a specific key |

# %% [markdown]
# Declaration of Dictionary

# %%
# Declaring a dictionary
student = {
    "name": "Kartik",
    "age": 21,
    "branch": "Machine Learning"
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Kartik', 'age': 21, 'branch': 'Machine Learning'}

# %% [markdown]
# 1. dict[Keys]

# %%
# Student record dictionary
student = {
    "name": "Arjun",
    "course": "Python",
    "marks": 85

}

# Accessing values using keys
student_name = student["name"]
student_marks = student["marks"]

print("Name:", student_name)   # Output: Arjun
print("Marks:", student_marks) # Output: 85
# Out:
# Name: Arjun
# Marks: 85

# %% [markdown]
# 2. get() — Fetch value by key safely

# %%
person = {"name": "Alex", "age": 25, "city": "Mumbai"}

# Fetch existing key
print(person.get("age"))        # Output: Alex

# Fetch non-existing key
print(person.get("country"))     # Output: None
# Out:
# 25
# None

# %% [markdown]
# 3. keys ()

# %%
person = {"name": "Alex", "age": 25, "city": "Mumbai", "Country":"India"}

# Get all keys
print(person.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'Country'])

# %% [markdown]
# 4. values ()

# %%
person = {"name": "Alex", "age": 25, "city": "Mumbai"}

# Get all values
print(person.values())
# Out:
# dict_values(['Alex', 25, 'Mumbai'])

# %% [markdown]
# 5. items ()

# %%
person = {"name": "Alex", "age": 25, "city": "Mumbai"}

# Get all key-value pairs
print(person.items())
# Out:
# dict_items([('name', 'Alex'), ('age', 25), ('city', 'Mumbai')])

# %% [markdown]
# 6. pop ()

# %%
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
print (person)

# Remove a key and get its value
removed_value = person.pop("age")
print("Removed value:", removed_value)
print(person)

# %% [markdown]
# # Python Sets — DSA Theory
#
# A **Set** in Python is an **unordered, mutable collection** of unique elements.
#
# ### Characteristics:
#
# * **Unique Elements:** Automatically removes duplicate values.
# * **Unordered:** Items do not have a defined order or index.
# * **Mutable:** You can add or remove elements, but elements themselves must be immutable.
# * **Fast Membership Testing:** Highly optimized for checking if an item exists ($O(1)$ average time complexity).
#
# ---
#
# ### Core Operations in Sets:
#
# | Operation | Description |
# | :--- | :--- |
# | `add()` | Add an element to the set |
# | `remove()` | Remove a specific element (raises error if missing) |
# | `discard()` | Remove a specific element (no error if missing) |
# | `union()` | Combine elements from two sets (`set1 \| set2`) |
# | `intersection()` | Return common elements in both sets (`set1 & set2`) |
# | `difference()` | Return elements present in first set but not second (`set1 - set2`) |

# %% [markdown]
# Declaring a Set

# %%
my_set = {1, 2, 3, 4, 5}
print("Initial Set:", my_set)
print (type(my_set))
# Out:
# Initial Set: {1, 2, 3, 4, 5}
# <class 'set'>

# %% [markdown]
# 1. add ()

# %%
my_set = {1, 2, 3}
my_set.add(4)
my_set.add(6)
my_set.add(7)
print("After add:", my_set)
# Out:
# After add: {1, 2, 3, 4, 6, 7}

# %% [markdown]
# 2. remove ()

# %%
my_set = {1, 2, 3,"Apple","car"}
my_set.remove("car")
print("After remove:", my_set)
# Out:
# After remove: {1, 2, 3, 'Apple'}

# %% [markdown]
# 3. discard ()

# %%
my_set = {1, 2, 3}
my_set.discard(6)  # Won't raise error
print("After discard:", my_set)
# Out:
# After discard: {1, 2, 3}

# %% [markdown]
# 4. Union ()

# %%
set1 = {1, 2, 3,5}
set2 = {3, 4, 5,4}
result = set2.union(set1)
print("Union:", result)
# Out:
# Union: {1, 2, 3, 4, 5}

# %% [markdown]
# 5. Intersection ()

# %%
set1 = {1, 2,4,4}
set2 = {2, 3, 4,5,6}
result = set1.intersection(set2)
print("Intersection:", result)
# Out:
# Intersection: {2, 4}

# %% [markdown]
# 6. Diffrence ()

# %%
set_a = {1, 2, 3, 4, 5}
set_b = {4, 5, 6, 7}

# Using - operator performs difference
result = set_a - set_b

print("Elements in A but not in B:", result)
# Output: {1, 2, 3}
# Out:
# Elements in A but not in B: {1, 2, 3}
